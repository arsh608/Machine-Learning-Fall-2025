# %% [markdown]
# # MACHINE LEARNING LAB 01

# %% [markdown]
# # TASK 1

# %%
import pandas as pd
import numpy as np

data = np.array([
    [40, 5, 6, 60, 2],
    [55, 6, 7, 70, 3],
    [30, 3, 4, 40, 1],
    [45, 4, 5, 50, 2],
    [60, 7, 8, 80, 4],
    [25, 2, 3, 30, 1],
    [50, 6, 6, 65, 3],
    [35, 3, 4, 45, 1],
    [42, 5, 5, 55, 2],
    [20, 1, 2, 20, 0]
])

df1 = pd.DataFrame(data, columns=['test_score','writing_skills','reading_skill','attendance','study_hours'])
print(df1)
# Out:
#    test_score  writing_skills  reading_skill  attendance  study_hours
# 0          40               5              6          60            2
# 1          55               6              7          70            3
# 2          30               3              4          40            1
# 3          45               4              5          50            2
# 4          60               7              8          80            4
# 5          25               2              3          30            1
# 6          50               6              6          65            3
# 7          35               3              4          45            1
# 8          42               5              5          55            2
# 9          20               1              2          20            0

# %% [markdown]
# # TASK 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cancer_patient_dataset.csv")
df.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# 4                     7             7                     6  ...        3
#
# ...

# %%
print("Unique categories in target:", df['Level'].unique())
# Out:
# Unique categories in target: ['Low' 'Medium' 'High']

# %%
print("Columns:", df.columns)
print("First 50 records:\n", df.head(50))
print("Last 30 records:\n", df.tail(30))
print("Info:")
print(df.info())
print("Shape:", df.shape)
print("Memory usage:", df.memory_usage().sum())
# Out:
# Columns: Index(['index', 'Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')
# First 50 records:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0       0         P1   33       1              2            4             5
# 1       1        P10   17       1              3            1             5
# 2       2       P100   35       1              4            5             6
# 3       3      P1000   37       1              7            7             7
# 4       4       P101   46       1              6            8             7
# ...

# %%
print("Number of columns:", df.shape[1])
print("Number of samples:", df.shape[0])
# Out:
# Number of columns: 26
# Number of samples: 1000

# %%
print(df['Level'].value_counts())

df['Level'].value_counts().plot(kind='bar', title="Category Distribution")
plt.show()
# Out:
# Level
# High      365
# Medium    332
# Low       303
# Name: count, dtype: int64

# %%
G = df.loc[550:900, 'Gender':'Coughing of Blood']
G.to_csv("G2.csv", index=False)

print(G.describe(include='all'))
# Out:
#            Gender  Air Pollution  Alcohol use  Dust Allergy  \
# count  351.000000     351.000000   351.000000    351.000000
# mean     1.396011       3.988604     4.749288      5.319088
# std      0.489765       2.042376     2.622941      1.921504
# min      1.000000       1.000000     1.000000      1.000000
# 25%      1.000000       2.000000     2.000000      4.000000
# 50%      1.000000       4.000000     5.000000      6.000000
# 75%      2.000000       6.000000     7.000000      7.000000
# max      2.000000       8.000000     8.000000      8.000000
#
#        OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count            351.000000    351.000000            351.000000
# mean               4.974359      4.726496              4.472934
# std                2.084480      2.112374              1.823257
# min                1.000000      1.000000              1.000000
# 25%                3.000000      3.000000              3.000000
# ...

# %%
H = df.iloc[-20:, df.columns.get_loc('Shortness of Breath'):df.columns.get_loc('Frequent Cold')+1]
H.to_csv("H2.csv", index=False)

print(H.describe(include='all'))
# Out:
#        Shortness of Breath   Wheezing  Swallowing Difficulty  \
# count            20.000000  20.000000               20.00000
# mean              5.400000   3.650000                3.95000
# std               2.542274   2.621269                2.37254
# min               2.000000   1.000000                1.00000
# 25%               3.750000   1.000000                1.75000
# 50%               5.000000   2.000000                4.00000
# 75%               7.500000   7.000000                6.00000
# max               9.000000   7.000000                8.00000
#
#        Clubbing of Finger Nails  Frequent Cold
# count                  20.00000      20.000000
# mean                    4.05000       4.650000
# std                     1.79106       1.496487
# min                     2.00000       2.000000
# 25%                     2.00000       4.000000
# 50%                     4.00000       4.000000
# 75%                     5.00000       6.000000
# ...

# %%
I = df.loc[[110,220,360,440,656,778,202,889], :]
print("Average Alcohol Use:", I['Alcohol use'].mean())
# Out:
# Average Alcohol Use: 5.625

# %% [markdown]
# # TASK 3

# %%
df['Age'].hist()
plt.title("Age Distribution")
plt.show()

# %%
plt.figure(figsize=(10,6))

numeric_df = df.select_dtypes(include=['int64','float64'])

sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap (Numeric Features Only)")
plt.show()

# %%
sns.histplot(df['Age'], kde=True)
plt.title("Distribution of Age")
plt.show()

sns.histplot(df['Frequent Cold'], kde=True)
plt.title("Distribution of Frequent Cold")
plt.show()

# %%
sns.boxplot(x=df['Obesity'])
plt.title("Outliers in Obesity")
plt.show()
