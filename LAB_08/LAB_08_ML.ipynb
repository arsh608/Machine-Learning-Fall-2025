# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
data = pd.read_csv("CarPrice_Assignment.csv")
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
categorical_cols = data.select_dtypes(include='object').columns
le = LabelEncoder()
for col in categorical_cols:
    data[col] = le.fit_transform(data[col])

plt.figure(figsize=(12,10))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
X = data.drop('price', axis=1)
y = data['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)

# %%
print("Training R2 Score:", r2_score(y_train, y_train_pred))
print("Training MSE:", mean_squared_error(y_train, y_train_pred))
print("Training MAE:", mean_absolute_error(y_train, y_train_pred))

print("Testing R2 Score:", r2_score(y_test, y_test_pred))
print("Testing MSE:", mean_squared_error(y_test, y_test_pred))
print("Testing MAE:", mean_absolute_error(y_test, y_test_pred))
# Out:
# Training R2 Score: 0.9135672116926564
# Training MSE: 5268045.35823092
# Training MAE: 1786.065474428225
# Testing R2 Score: 0.842553569795434
# Testing MSE: 10908578.081287203
# Testing MAE: 2169.2654381891216

# %%
plt.figure(figsize=(10,5))
plt.scatter(y_train, y_train_pred, label='Train', alpha=0.7)
plt.scatter(y_test, y_test_pred, label='Test', alpha=0.7)
plt.plot([min(y), max(y)], [min(y), max(y)], color='red', linestyle='--')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted Prices')
plt.legend()
plt.show()

# %%
#@title TASK 2
data2 = pd.read_csv("electricity_bill_dataset.csv")
data2.head()
# Out:
#    Fan  Refrigerator  AirConditioner  Television  Monitor  MotorPump  Month  \
# 0   16          23.0             2.0         6.0      1.0          0     10
# 1   19          22.0             2.0         3.0      1.0          0      5
# 2    7          20.0             2.0         6.0      7.0          0      7
# 3    7          22.0             3.0        21.0      1.0          0      6
# 4   11          23.0             2.0        11.0      1.0          0      2
#
#         City                                    Company  MonthlyHours  \
# 0  Hyderabad                    Tata Power Company Ltd.           384
# 1   Vadodara                                       NHPC           488
# 2     Shimla                            Jyoti Structure           416
# 3     Mumbai                            Power Grid Corp           475
# 4     Mumbai  Ratnagiri Gas and Power Pvt. Ltd. (RGPPL)           457
#
#    TariffRate  ElectricityBill
# 0         8.4           3225.6
# ...

# %%
categorical_cols2 = data2.select_dtypes(include='object').columns
le2 = LabelEncoder()
for col in categorical_cols2:
    data2[col] = le2.fit_transform(data2[col])

data2.describe()

plt.figure(figsize=(10,8))
sns.heatmap(data2.corr(), annot=True, cmap='coolwarm')
plt.show()

features = data2.columns.drop('ElectricityBill')
for f in features:
    plt.scatter(data2[f], data2['ElectricityBill'])
    plt.xlabel(f)
    plt.ylabel('ElectricityBill')
    plt.title(f'{f} vs ElectricityBill')
    plt.show()
